# %%
import numpy as np
import seaborn as sns

data1 = np.random.lognormal(100, 0.2, 1000)
data2 = np.random.lognormal(105, 0.2, 1000)
sns.histplot(data1)
# Out:
# <Axes: ylabel='Count'>

# %%
sns.histplot(data2)
# Out:
# <Axes: ylabel='Count'>

# %%
np.log(data1).mean(), np.log(data2).mean()
# Out:
# (99.99909695537833, 104.99493238674654)
